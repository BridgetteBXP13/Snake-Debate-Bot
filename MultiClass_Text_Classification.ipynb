# %% [markdown]
# # Testing Multi-Class Classifictaion
#
# With typical models so far for the chatbot the input dataset has heavily struggled as it is a very small dataset and there are many different ways to write a sentence. This causes the accuracy to be very low as well as the fact that there are about 50 different categories (classes) and only about 350 entries. I have already tested Sentence Similarity as well with interesting results. A huge con to sentence similarity is that it would require a model for each class and would likely still not be the most accurate. I am going to test Muli-Class Classification with a well made pre-built model to hopefully achive an higher accuracy.

# %% [markdown]
# ## The Model
# For this I found the model Distilbert-base-uncased, Bert is a very well known and well made model. I am hoping despite my limited data and high amount of classes it will be able to achieve a higher accuracy than previous models.
#
# This model can be found here:
#
# https://huggingface.co/distilbert-base-uncased?text=The+goal+of+life+is+%5BMASK%5D.
#
# I heavily utilized a guide in order to achieve this in Tensorflow and not PyTorch as that is what I wanted to use for this project.
#
# This guide can be found here:
#
# https://www.sunnyville.ai/fine-tuning-distilbert-multi-class-text-classification-using-transformers-and-tensorflow/

# %% [markdown]
# ## Prepping Our Libraries/Classes

# %%
# Installing the latest version of transformers
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-hflp2hep
#   Running command git clone -q https://github.com/huggingface/transformers.git /tmp/pip-req-build-hflp2hep
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.25.0.dev0) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.25.0.dev0) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.25.0.dev0) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.25.0.dev0) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.25.0.dev0) (6.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 5.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.25.0.dev0) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.25.0.dev0) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 49.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.25.0.dev0) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.0.dev0) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.25.0.dev0) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.25.0.dev0) (3.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.25.0.dev0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.25.0.dev0) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.25.0.dev0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.25.0.dev0) (1.24.3)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517) ... done
#   Created wheel for transformers: filename=transformers-4.25.0.dev0-py3-none-any.whl size=5603919 sha256=2f060b4ac27ced9d9767e0b4eb6401c88203cfa22515cfdb63ad100d3354f734
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9kj0tdew/wheels/90/a5/44/6bcd83827c8a60628c5ad602f429cd5076bcce5f2a90054947
# Successfully built transformers
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.2 transformers-4.25.0.dev0

# %%
# Importing our needed libraries
from transformers import DistilBertTokenizer
from transformers import TFDistilBertForSequenceClassification
import tensorflow as tf
import pandas as pd

# %% [markdown]
# ## Data Processing
# Here we will load in my inputs and category dataset from github.
#
# This Dataset can be found here:
#
# https://github.com/BridgetteBXP13/CS-4395.001---Human-Language-Technologies/blob/main/Chatbot/Data/Inputs.csv

# %%
# Import our data
url = 'https://raw.githubusercontent.com/BridgetteBXP13/CS-4395.001---Human-Language-Technologies/main/Chatbot/Data/Inputs.csv'
df = pd.read_csv(url)
print("\nOur loaded dataframe:\n")
df.head
# Out:
# Our loaded dataframe:
# <bound method NDFrame.head of                                                  Input        Category
# 0                                Snakes are aggressive        Behavior
# 1                                 Are they aggressive         Behavior
# 2    Snakes will not bite unless you try to approac...        Behavior
# 3                              Do snakes like to bite?        Behavior
# 4                                  Snakes chase people        Behavior
# ..                                                 ...             ...
# 325                             Snakes are emotionless           Brain
# 326                               Can snakes grow hair            Body
# 327                                    Snakes are mean        Behavior
# 328                            Why should snakes exist  Snake Benefits
# 329                                Are snakes any good  Snake Benefits
#
# [330 rows x 2 columns]>

# %%
# Display our categories and their counts
print("\nNumber of Categories:", len(df.Category.unique()))
print("\nOur Categories:")
print(df.Category.unique())
print("\nCounts of each Category:")
print(df.Category.value_counts())
# Out:
# Number of Categories: 51
#
# Our Categories:
# ['Behavior' 'Body' 'Brain' 'Bye' 'Creators' 'Crossbreeding'
#  'Dangerous Snakes' 'Deaf' 'Definition' 'Diamond' 'Dislocate Jaws' 'Eat'
#  'Endangered' 'Escape' 'Evil' 'Eyesight' 'Fear' 'Flying snakes' 'Generic'
#  'Greeting' 'Infared' 'Kill Snakes' 'Lay Eggs' 'Legless Lizard' 'Legs'
#  'Live Forever' 'Lizards Discourage' 'Misunderstand' 'Mother Snake'
#  'Music' 'Musk' 'Name' 'Pairs' 'Pet Snakes' 'Poisonous' 'Pupils' 'Purpose'
#  'Rattle' 'Scared' 'Size' 'Slimy' 'Smell' 'Snake Attraction'
#  'Snake Benefits' 'Snake Bite' 'Suffication' 'Swim' 'Tails' 'Topics'
#  'Understand' 'Venomous']
#
# Counts of each Category:
# Pet Snakes            17
# Body                  16
# Behavior              12
# Eat                   11
# Understand            10
# Eyesight              10
# Venomous              10
# Pairs                  8
# Brain                  8
# Misunderstand          8
# Generic                8
# Legs                   8
# Snake Benefits         8
# Kill Snakes            7
# Dislocate Jaws         7
# Dangerous Snakes       7
# Fear                   7
# Smell                  7
# Rattle                 6
# Musk                   6
# Mother Snake           6
# Deaf                   6
# Suffication            6
# Evil                   6
# Endangered             6
# Infared                6
# Snake Bite             5
# Pupils                 5
# Snake Attraction       5
# Swim                   5
# Tails                  5
# Scared                 5
# Topics                 5
# Music                  5
# Live Forever           5
# Lay Eggs               5
# Crossbreeding          5
# Definition             5
# Flying snakes          5
# Greeting               5
# Lizards Discourage     5
# Bye                    5
# Legless Lizard         5
# Escape                 4
# Poisonous              4
# Slimy                  4
# Size                   4
# Name                   3
# Purpose                3
# Diamond                3
# Creators               3
# Name: Category, dtype: int64

# %%
# Adding a column of category codes (cat codes)
df['encoded_cat'] = df.Category.astype('category').cat.codes
print("\nOur new dataframe with cat codes:\n")
df.head()
# Out:
# Our new dataframe with cat codes:
# 'Greeting'

# %%
# Converting Our Data to Lists
data_input_texts = df.Input.to_list()
data_cats = df.encoded_cat.to_list()
print("\nThe first five of our input text list:")
print(data_input_texts[:5])
print("\nThe first five cat codes for the input text list:")
print(data_cats[:5])
# Out:
# The first five of our input text list:
# ['Snakes are aggressive', 'Are they aggressive ', 'Snakes will not bite unless you try to approach/handle them.', 'Do snakes like to bite?', 'Snakes chase people']
#
# The first five cat codes for the input text list:
# [0, 0, 0, 0, 0]

# %%
# Splitting Into Train, Test, & Validation
from sklearn.model_selection import train_test_split

# Split Train & Validate
train_inputs, val_inputs, train_cats, val_cats = train_test_split(data_input_texts, data_cats, test_size=0.2, random_state=1234)
# Split Train & Test
train_inputs, test_inputs, train_cats, test_cats = train_test_split(train_inputs, train_cats, test_size=.1, random_state=1234)

# %% [markdown]
# ## Tensorflow
#
# ### Creating Model and Prepping Data

# %%
# Tokenizing and Encoding our input text
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
train_encodings = tokenizer(train_inputs, truncation=True, padding=True)
val_encodings = tokenizer(val_inputs, truncation=True, padding=True)
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %%
# Creating our Tensorflow Dataset Objects
train_dataset = tf.data.Dataset.from_tensor_slices((
    dict(train_encodings),
    train_cats
))
val_dataset = tf.data.Dataset.from_tensor_slices((
    dict(val_encodings),
    val_cats
))

# %% [markdown]
# ### Fine Tuning the Model

# %%
# Building & Compliling the Model
model = TFDistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=51)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer, loss=model.hf_compute_loss, metrics=['accuracy'])
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['activation_13', 'vocab_layer_norm', 'vocab_transform', 'vocab_projector']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier', 'dropout_99', 'classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-be725aaf2613> in <module>
#       2 model = TFDistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=51)
#       3
# ----> 4 optimizer = tf.keras.optimizers.AdamWeightDecay(learning_rate=5e-5)
#       5 model.compile(optimizer=optimizer, loss=model.hf_compute_loss, metrics=['accuracy'])
#
# AttributeError: module 'keras.api._v2.keras.optimizers' has no attribute 'AdamWeightDecay'

# %%
# Training & Fine Tuning the Model
model.fit(train_dataset.shuffle(1000).batch(32), epochs=100, batch_size=32,
          validation_data=val_dataset.shuffle(1000).batch(32))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 36s 4s/step - loss: 0.2838 - accuracy: 0.9958 - val_loss: 1.7521 - val_accuracy: 0.5909
# Epoch 2/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.2390 - accuracy: 0.9916 - val_loss: 1.6775 - val_accuracy: 0.5909
# Epoch 3/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.2188 - accuracy: 0.9958 - val_loss: 1.6055 - val_accuracy: 0.6061
# Epoch 4/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.1718 - accuracy: 0.9958 - val_loss: 1.6204 - val_accuracy: 0.6212
# Epoch 5/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.1470 - accuracy: 0.9958 - val_loss: 1.6046 - val_accuracy: 0.6364
# Epoch 6/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.1351 - accuracy: 0.9958 - val_loss: 1.5681 - val_accuracy: 0.6212
# Epoch 7/100
# 8/8 [==============================] - 32s 4s/step - loss: 0.1211 - accuracy: 0.9958 - val_loss: 1.5398 - val_accuracy: 0.6818
# Epoch 8/100
# 8/8 [==============================] - 36s 4s/step - loss: 0.1091 - accuracy: 0.9958 - val_loss: 1.5240 - val_accuracy: 0.6818
# Epoch 9/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0926 - accuracy: 0.9958 - val_loss: 1.5258 - val_accuracy: 0.6212
# Epoch 10/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0862 - accuracy: 0.9958 - val_loss: 1.5564 - val_accuracy: 0.6212
# Epoch 11/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0807 - accuracy: 0.9958 - val_loss: 1.5283 - val_accuracy: 0.6364
# Epoch 12/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0691 - accuracy: 0.9958 - val_loss: 1.5011 - val_accuracy: 0.6667
# Epoch 13/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0651 - accuracy: 0.9958 - val_loss: 1.4925 - val_accuracy: 0.6212
# Epoch 14/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0610 - accuracy: 0.9958 - val_loss: 1.5092 - val_accuracy: 0.6364
# Epoch 15/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0587 - accuracy: 0.9916 - val_loss: 1.5100 - val_accuracy: 0.6364
# Epoch 16/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0557 - accuracy: 0.9958 - val_loss: 1.5251 - val_accuracy: 0.6515
# Epoch 17/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0527 - accuracy: 0.9958 - val_loss: 1.5070 - val_accuracy: 0.6212
# Epoch 18/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0456 - accuracy: 0.9958 - val_loss: 1.5106 - val_accuracy: 0.6364
# Epoch 19/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0436 - accuracy: 0.9958 - val_loss: 1.4958 - val_accuracy: 0.6515
# Epoch 20/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0441 - accuracy: 0.9958 - val_loss: 1.4862 - val_accuracy: 0.6515
# Epoch 21/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0394 - accuracy: 0.9958 - val_loss: 1.4908 - val_accuracy: 0.6364
# Epoch 22/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 1.4980 - val_accuracy: 0.6212
# Epoch 23/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0370 - accuracy: 0.9958 - val_loss: 1.4873 - val_accuracy: 0.6515
# Epoch 24/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0387 - accuracy: 0.9916 - val_loss: 1.4894 - val_accuracy: 0.6515
# Epoch 25/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0333 - accuracy: 0.9958 - val_loss: 1.4982 - val_accuracy: 0.6515
# Epoch 26/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 1.5013 - val_accuracy: 0.6515
# Epoch 27/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 1.5085 - val_accuracy: 0.6515
# Epoch 28/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0300 - accuracy: 0.9958 - val_loss: 1.5208 - val_accuracy: 0.6515
# Epoch 29/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 1.5155 - val_accuracy: 0.6364
# Epoch 30/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0289 - accuracy: 0.9958 - val_loss: 1.5056 - val_accuracy: 0.6364
# Epoch 31/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0278 - accuracy: 0.9916 - val_loss: 1.5088 - val_accuracy: 0.6515
# Epoch 32/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0259 - accuracy: 0.9958 - val_loss: 1.5021 - val_accuracy: 0.6515
# Epoch 33/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0307 - accuracy: 0.9916 - val_loss: 1.4954 - val_accuracy: 0.6667
# Epoch 34/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 1.5084 - val_accuracy: 0.6515
# Epoch 35/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0241 - accuracy: 0.9958 - val_loss: 1.5082 - val_accuracy: 0.6515
# Epoch 36/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0229 - accuracy: 0.9958 - val_loss: 1.5121 - val_accuracy: 0.6515
# Epoch 37/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 1.5152 - val_accuracy: 0.6667
# Epoch 38/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0228 - accuracy: 0.9916 - val_loss: 1.5269 - val_accuracy: 0.6515
# Epoch 39/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0240 - accuracy: 0.9916 - val_loss: 1.5332 - val_accuracy: 0.6515
# Epoch 40/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0233 - accuracy: 0.9916 - val_loss: 1.5359 - val_accuracy: 0.6667
# Epoch 41/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0210 - accuracy: 0.9916 - val_loss: 1.5432 - val_accuracy: 0.6667
# Epoch 42/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0231 - accuracy: 0.9958 - val_loss: 1.5501 - val_accuracy: 0.6515
# Epoch 43/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0264 - accuracy: 0.9916 - val_loss: 1.5473 - val_accuracy: 0.6515
# Epoch 44/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0206 - accuracy: 0.9958 - val_loss: 1.5224 - val_accuracy: 0.6818
# Epoch 45/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0203 - accuracy: 0.9958 - val_loss: 1.5186 - val_accuracy: 0.6667
# Epoch 46/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 1.5355 - val_accuracy: 0.6818
# Epoch 47/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0186 - accuracy: 0.9958 - val_loss: 1.5442 - val_accuracy: 0.6515
# Epoch 48/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0208 - accuracy: 0.9916 - val_loss: 1.5551 - val_accuracy: 0.6515
# Epoch 49/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0177 - accuracy: 0.9958 - val_loss: 1.5538 - val_accuracy: 0.6667
# Epoch 50/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0174 - accuracy: 0.9958 - val_loss: 1.5471 - val_accuracy: 0.6667
# Epoch 51/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0178 - accuracy: 0.9958 - val_loss: 1.5425 - val_accuracy: 0.6667
# Epoch 52/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 1.5395 - val_accuracy: 0.6667
# Epoch 53/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0157 - accuracy: 0.9958 - val_loss: 1.5477 - val_accuracy: 0.6667
# Epoch 54/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0164 - accuracy: 0.9958 - val_loss: 1.5571 - val_accuracy: 0.6667
# Epoch 55/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 1.5678 - val_accuracy: 0.6667
# Epoch 56/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 1.5693 - val_accuracy: 0.6667
# Epoch 57/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0153 - accuracy: 0.9916 - val_loss: 1.5621 - val_accuracy: 0.6818
# Epoch 58/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 1.5614 - val_accuracy: 0.6667
# Epoch 59/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0169 - accuracy: 0.9916 - val_loss: 1.5603 - val_accuracy: 0.6667
# Epoch 60/100
# 8/8 [==============================] - 34s 4s/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 1.5597 - val_accuracy: 0.6667
# Epoch 61/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 1.5695 - val_accuracy: 0.6667
# Epoch 62/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0147 - accuracy: 0.9916 - val_loss: 1.5838 - val_accuracy: 0.6515
# Epoch 63/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0145 - accuracy: 0.9916 - val_loss: 1.5788 - val_accuracy: 0.6515
# Epoch 64/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0148 - accuracy: 0.9916 - val_loss: 1.5752 - val_accuracy: 0.6667
# Epoch 65/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0151 - accuracy: 0.9916 - val_loss: 1.5835 - val_accuracy: 0.6667
# Epoch 66/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0140 - accuracy: 0.9916 - val_loss: 1.5829 - val_accuracy: 0.6667
# Epoch 67/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 1.5986 - val_accuracy: 0.6515
# Epoch 68/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0142 - accuracy: 0.9958 - val_loss: 1.6075 - val_accuracy: 0.6667
# Epoch 69/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 1.6042 - val_accuracy: 0.6667
# Epoch 70/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 1.6037 - val_accuracy: 0.6667
# Epoch 71/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.6023 - val_accuracy: 0.6667
# Epoch 72/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0143 - accuracy: 0.9958 - val_loss: 1.6051 - val_accuracy: 0.6667
# Epoch 73/100
# 8/8 [==============================] - 32s 4s/step - loss: 0.0125 - accuracy: 0.9916 - val_loss: 1.6028 - val_accuracy: 0.6667
# Epoch 74/100
# 8/8 [==============================] - 32s 4s/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 1.6032 - val_accuracy: 0.6667
# Epoch 75/100
# 8/8 [==============================] - 32s 4s/step - loss: 0.0139 - accuracy: 0.9916 - val_loss: 1.6087 - val_accuracy: 0.6667
# Epoch 76/100
# 8/8 [==============================] - 32s 4s/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 1.6103 - val_accuracy: 0.6667
# Epoch 77/100
# 8/8 [==============================] - 32s 4s/step - loss: 0.0108 - accuracy: 0.9958 - val_loss: 1.6138 - val_accuracy: 0.6667
# Epoch 78/100
# 8/8 [==============================] - 32s 4s/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 1.6177 - val_accuracy: 0.6667
# Epoch 79/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 1.6565 - val_accuracy: 0.6515
# Epoch 80/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 1.6286 - val_accuracy: 0.6515
# Epoch 81/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.6166 - val_accuracy: 0.6818
# Epoch 82/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0146 - accuracy: 0.9958 - val_loss: 1.6159 - val_accuracy: 0.6818
# Epoch 83/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0148 - accuracy: 0.9916 - val_loss: 1.6297 - val_accuracy: 0.6667
# Epoch 84/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0159 - accuracy: 0.9916 - val_loss: 1.6650 - val_accuracy: 0.6515
# Epoch 85/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 1.6245 - val_accuracy: 0.6667
# Epoch 86/100
# 8/8 [==============================] - 30s 4s/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 1.6287 - val_accuracy: 0.6667
# Epoch 87/100
# 8/8 [==============================] - 34s 4s/step - loss: 0.0129 - accuracy: 0.9916 - val_loss: 1.6357 - val_accuracy: 0.6970
# Epoch 88/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0118 - accuracy: 0.9916 - val_loss: 1.6316 - val_accuracy: 0.6970
# Epoch 89/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0107 - accuracy: 0.9958 - val_loss: 1.6305 - val_accuracy: 0.6970
# Epoch 90/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 1.6477 - val_accuracy: 0.6970
# Epoch 91/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0110 - accuracy: 0.9958 - val_loss: 1.6338 - val_accuracy: 0.6970
# Epoch 92/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0108 - accuracy: 0.9958 - val_loss: 1.6279 - val_accuracy: 0.6970
# Epoch 93/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0106 - accuracy: 0.9958 - val_loss: 1.6356 - val_accuracy: 0.6818
# Epoch 94/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0107 - accuracy: 0.9958 - val_loss: 1.6444 - val_accuracy: 0.6667
# Epoch 95/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 1.6567 - val_accuracy: 0.6818
# Epoch 96/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 1.6582 - val_accuracy: 0.6818
# Epoch 97/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.6589 - val_accuracy: 0.6818
# Epoch 98/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0110 - accuracy: 0.9958 - val_loss: 1.6550 - val_accuracy: 0.6818
# Epoch 99/100
# 8/8 [==============================] - 31s 4s/step - loss: 0.0107 - accuracy: 0.9916 - val_loss: 1.6505 - val_accuracy: 0.6818
# Epoch 100/100
# 8/8 [==============================] - 32s 4s/step - loss: 0.0083 - accuracy: 0.9958 - val_loss: 1.6488 - val_accuracy: 0.6818

# %%
# Save our Model
model.save_pretrained("models/")
tokenizer.save_pretrained("tokenizers/")
# Out:
# ('tokenizers/tokenizer_config.json',
#  'tokenizers/special_tokens_map.json',
#  'tokenizers/vocab.txt',
#  'tokenizers/added_tokens.json')

# %%
# Loading (if needed)
loaded_tokenizer = DistilBertTokenizer.from_pretrained("tokenizers/")
loaded_model = TFDistilBertForSequenceClassification.from_pretrained("models/")
# Out:
# Some layers from the model checkpoint at models/ were not used when initializing TFDistilBertForSequenceClassification: ['dropout_19']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at models/ and are newly initialized: ['dropout_79']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Making Predictions

# %%
# Remember our input_tests from earlier!
# We will loop through each test input and print it along with the predicted category
for test_input in test_inputs:
  predict_input = loaded_tokenizer.encode(test_input,
                                 truncation=True,
                                 padding=True,
                                 return_tensors="tf")

  print("\nInput: ", test_input)
  output = loaded_model(predict_input)[0]

  prediction_cat_code = tf.argmax(output, axis=1).numpy()[0]

  pred_cat = ''
  if prediction_cat_code == 0:
    pred_cat = 'Behavior' 
  elif prediction_cat_code == 1:
    pred_cat = 'Body'
  elif prediction_cat_code == 2:
    pred_cat = 'Brain'
  elif prediction_cat_code == 3:
    pred_cat = 'Bye'
  elif prediction_cat_code == 4:
    pred_cat = 'Creators'
  elif prediction_cat_code == 5:
    pred_cat = 'Crossbreeding'
  elif prediction_cat_code == 6:
    pred_cat = 'Dangerous Snakes'
  elif prediction_cat_code == 7:
    pred_cat = 'Deaf'
  elif prediction_cat_code == 8:
    pred_cat = 'Definition'
  elif prediction_cat_code == 9:
    pred_cat = 'Diamond'
  elif prediction_cat_code == 10:
    pred_cat = 'Dislocate Jaws'
  elif prediction_cat_code == 11:
    pred_cat = 'Eat'
  elif prediction_cat_code == 12:
    pred_cat = 'Endangered'
  elif prediction_cat_code == 13:
    pred_cat = 'Escape'
  elif prediction_cat_code == 14:
    pred_cat = 'Evil'
  elif prediction_cat_code == 15:
    pred_cat = 'Eyesight'
  elif prediction_cat_code == 16:
    pred_cat = 'Fear'
  elif prediction_cat_code == 17:
    pred_cat = 'Flying Snakes'
  elif prediction_cat_code == 18:
    pred_cat = 'Generic'
  elif prediction_cat_code == 19:
    pred_cat = 'Greeting'
  elif prediction_cat_code == 20:
    pred_cat = 'Infared'
  elif prediction_cat_code == 21:
    pred_cat = 'Kill Snakes'
  elif prediction_cat_code == 22:
    pred_cat = 'Lay Eggs'
  elif prediction_cat_code == 23:
    pred_cat = 'Legless Lizard'
  elif prediction_cat_code == 24:
    pred_cat = 'Legs'
  elif prediction_cat_code == 25:
    pred_cat = 'Live Forever'
  elif prediction_cat_code == 26:
    pred_cat = 'Lizards Discourage'
  elif prediction_cat_code == 27:
    pred_cat = 'Misunderstand'
  elif prediction_cat_code == 28:
    pred_cat = 'Mother Snake'
  elif prediction_cat_code == 29:
    pred_cat = 'Music'
  elif prediction_cat_code == 30:
    pred_cat = 'Musk'
  elif prediction_cat_code == 31:
    pred_cat = 'Name'
  elif prediction_cat_code == 32:
    pred_cat = 'Pairs'
  elif prediction_cat_code == 33:
    pred_cat = 'Pet Snakes'
  elif prediction_cat_code == 34:
    pred_cat = 'Poisonous'
  elif prediction_cat_code == 35:
    pred_cat = 'Pupils'
  elif prediction_cat_code == 36:
    pred_cat = 'Purpose'
  elif prediction_cat_code == 37:
    pred_cat = 'Rattle'
  elif prediction_cat_code == 38:
    pred_cat = 'Scared'
  elif prediction_cat_code == 39:
    pred_cat = 'Size'
  elif prediction_cat_code == 40:
    pred_cat = 'Slimy'
  elif prediction_cat_code == 41:
    pred_cat = 'Smell'
  elif prediction_cat_code == 42: 
    pred_cat = 'Snake Attraction'
  elif prediction_cat_code == 43:
    pred_cat = 'Snake Benefits'
  elif prediction_cat_code == 44:
    pred_cat = 'Snake Bite'
  elif prediction_cat_code == 45:
    pred_cat = 'Suffication'
  elif prediction_cat_code == 46:
    pred_cat = 'Swim'
  elif prediction_cat_code == 47:
    pred_cat = 'Tails'
  elif prediction_cat_code == 48:
    pred_cat = 'Topics'
  elif prediction_cat_code == 49:
    pred_cat = 'Understand'
  elif prediction_cat_code == 50:
    pred_cat = 'Venomous'

  print("Predicted Category: " + str(prediction_cat_code) + ": " + pred_cat)

print("Our Model got 20/27 Correct, that gives use an accuracy of 74% on our test data!")
# Out:
# Input:  Snakes can sting with their tails
# Predicted Category: 47: Tails
#
# Input:  Lizards without legs are snakes
# Predicted Category: 23: Legless Lizard
#
# Input:  Can snakes give live birth?
# Predicted Category: 28: Mother Snake
#
# Input:  Should we kill snakes
# Predicted Category: 21: Kill Snakes
#
# Input:  I see
# Predicted Category: 3: Bye
#
# Input:  Name?
# Predicted Category: 31: Name
#
# Input:  Snakes cannot strike underwater?
# Predicted Category: 17: Flying Snakes
#
# Input:  is it true that when rattlesnakes are babies that they let out all or most of their venom on their prey?
# Predicted Category: 37: Rattle
#
# Input:  Do snakes ever blink
# Predicted Category: 15: Eyesight
#
# Input:  Are there flying snakes
# Predicted Category: 1: Body
#
# Input:  Lizards have legs and snakes don't
# Predicted Category: 24: Legs
#
# Input:  Snakes don't have ears
# Predicted Category: 1: Body
#
# Input:  Why should snakes exist
# Predicted Category: 43: Snake Benefits
#
# Input:  They stink
# Predicted Category: 30: Musk
#
# Input:  Snakes don't smell
# Predicted Category: 41: Smell
#
# Input:  Snakes are dangerous pets
# Predicted Category: 33: Pet Snakes
#
# Input:  I don't like snakes
# Predicted Category: 0: Behavior
#
# Input:  Snakes are boring
# Predicted Category: 39: Size
#
# Input:  Snakes shouldn't exist
# Predicted Category: 43: Snake Benefits
#
# Input:  They smell
# Predicted Category: 41: Smell
#
# Input:  Snakes are lizards without legs
# Predicted Category: 23: Legless Lizard
#
# Input:  Snakes are terrible pets
# Predicted Category: 33: Pet Snakes
#
# Input:  Snakes can fly
# Predicted Category: 46: Swim
#
# Input:  I can use lizards to keep snakes away
# Predicted Category: 26: Lizards Discourage
#
# Input:  How big are pet snakes?
# Predicted Category: 33: Pet Snakes
#
# Input:  Snakes carry a diamond in their forehead
# Predicted Category: 9: Diamond
#
# Input:  Snakes are scary
# Predicted Category: 18: Generic
# Our Model got 20/27 Correct, that gives use an accuracy of 74% on our test data!
